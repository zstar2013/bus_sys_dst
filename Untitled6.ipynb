# %%
from xlwt import Workbook
import elec_options as elo
import feedback_data as fd
import datetime
import loadexcel as lc
date=datetime.date(2019,8,1)
vars_=[[7,13,"新能源"],[2,4,"闽运"],[5,6,"华威"],[5,6,"康驰"]]
data=lc.update_car_info_from_xml("example_data\\electric\\8月\\单车能耗汇总-公交集团8月.xlsx", "一公司", "", date=date)
result_1=elo.tim_data_elec_xny(data,vars_[0])
data=lc.update_car_info_from_xml("example_data\\electric\\8月\\福州公交八月份  83、161、K2线路车辆明细统计表.xlsx", "福州公交 八月份  83、161、K2线路车辆明细统计表", "", date=date)
result_2=elo.tim_data_elec_xny(data,vars_[1])
data=lc.update_car_info_from_xml("example_data\\electric\\8月\\华威8月.xlsx", "公交汇总", "", date=date)
result_3=elo.tim_data_elec_xny(data,vars_[2])
data=lc.update_car_info_from_xml("example_data\\electric\\8月\\康驰8月.xlsx", "按单车汇总", "", date=date)
result_4=elo.tim_data_elec_xny(data,vars_[3])
result=result_1.append(result_2).append(result_3).append(result_4)
#data_elec=result_data[result_data["power_type"]=="电"][["sub_car_id","electric_cost"]]
#newWb = Workbook()
# ws = newWb.add_sheet("反馈汇总表")
# ct.write_monthy_feedback_with_elec_sum_table(ws, date_)
# ws_ = newWb.add_sheet("单车汇总表")
# ct.write_monthy_feedback_detail_table(ws_, date_)
# newWb.save("output\\2019\\反馈数据\\9月\\9月带电耗反馈汇总表.xls")

# %%
remove_AY=lambda x:x.replace("闽AY","")
remove_A=lambda x:x.replace("闽A","")
result.iloc[:,1]=result.iloc[:,1].apply(float)
result.iloc[:,0]=result.iloc[:,0].apply(remove_AY)
result.iloc[:,0]=result.iloc[:,0].apply(remove_A)

# %%
result=result.drop(result[result["电量"]==0].index)
result.index=range(len(result))
result
# Out:
#          车号       电量 来源公司
# 0    05693D  1996.28  新能源
# 1    08732D  3967.97  新能源
# 2    09200D  4890.96  新能源
# 3    09912D  5035.53  新能源
# 4    03865D  5178.01  新能源
# 5    09023D  4085.70  新能源
# 6    09064D  5462.43  新能源
# 7    03815D  3603.29  新能源
# 8    01352D  3509.63  新能源
# 9    08138D  2846.24  新能源
# 10   03231D  4802.78  新能源
# 11   05692D  5101.54  新能源
# 12   09256D  4843.68  新能源
# 13   09231D  3635.64  新能源
# 14   01338D  5307.02  新能源
# 15   00709D  5864.62  新能源
# 16   06620D  4227.66  新能源
# 17   02001D  5404.62  新能源
# 18   03992D  5205.14  新能源
# 19   01120D  5788.12  新能源
# 20   01389D  5724.38  新能源
# 21   00756D  5672.85  新能源
# 22   09621D  5415.86  新能源
# 23   01316D  5393.57  新能源
# 24   01381D  5855.13  新能源
# 25   09293D  5033.06  新能源
# 26   08896D  2348.69  新能源
# 27   03838D  2434.95  新能源
# 28   02186D  2278.68  新能源
# 29   03878D  3018.30  新能源
# ..      ...      ...  ...
# 144  01183D  4153.87   华威
# 145  03162D  2008.69   华威
# 146  03205D  6196.94   华威
# 147  03823D  5546.60   华威
# 148  03866D  7019.53   华威
# 149  03938D  3697.94   华威
# 150  06223D  6039.41   华威
# 151  06229D  4405.93   华威
# 152  06269D  3003.48   华威
# 153  06285D  4408.43   华威
# 154  08603D  3502.51   华威
# 155  08612D  5771.58   华威
# 156  03218D  2274.21   华威
# 157  07163D  2329.13   华威
# 158  09072D  2487.11   华威
# 159  01103D  2750.40   康驰
# 160  03238D  2527.11   康驰
# 161  03800D  2560.66   康驰
# 162  05600D  2596.75   康驰
# 163  05686D  2826.44   康驰
# 164  06230D  2512.88   康驰
# 165  08135D  2912.29   康驰
# 166  08635D  2347.38   康驰
# 167  08655D  2525.76   康驰
# 168  08682D  1899.42   康驰
# 169  08711D  2916.24   康驰
# 170  08787D  2521.99   康驰
# 171  09962D  3067.52   康驰
# 172  03116D  1173.09   康驰
# 173  05771D  3351.80   康驰
#
# [174 rows x 3 columns]

# %%
re=result["车号"].value_counts()>1

# %%
re.index=range(len(re))
re
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# 158    False
# 159    False
# 160    False
# Name: 车号, Length: 161, dtype: bool

# %%
result.index=range(len(result))
